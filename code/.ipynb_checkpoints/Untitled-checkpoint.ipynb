# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import pandas as pd
import pymc3 as pm
import theano.tensor as tt

# %matplotlib inline

# %%
model = pm.Model()
grid = np.arange(-4, 4)
with model:
    demand = pm.Normal("demand", mu=0, sd=1, shape=1)
    cost = pm.Deterministic("mean", 5*tt.ge(demand, grid))

# %%
with model:
    step = pm.NUTS()
    trace = pm.sample(2000, tune=1000, init=None, step=step, njobs=2)
# Out:
# 100%|██████████| 3000/3000 [00:03<00:00, 913.20it/s]

# %%
pm.plots.traceplot(trace)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-5fc2f3ecadd7> in <module>()
# ----> 1 pm.plots.traceplot(trace)
#
# /usr/local/lib/python3.5/dist-packages/pymc3/plots/traceplot.py in traceplot(trace, varnames, transform, figsize, lines, combined, plot_transformed, grid, alpha, priors, prior_alpha, prior_style, ax, live_plot, skip_first, refresh_every, roll_over)
#     105                 colors = [h[-1][0].get_facecolor() for h in hist_objs]
#     106             else:
# --> 107                 artists = kdeplot_op(ax[i, 0], d, prior, prior_alpha, prior_style)[0]
#     108                 colors = [a[0].get_color() for a in artists]
#     109             ax[i, 0].set_title(str(v))
#
# /usr/local/lib/python3.5/dist-packages/pymc3/plots/artists.py in kdeplot_op(ax, data, prior, prior_alpha, prior_style)
#      30     for i, d in enumerate(data.T):
#      31         try:
# ---> 32             density, l, u = fast_kde(d)
#      33             x = np.linspace(l, u, len(density))
#      34             if prior is not None:
#
# /usr/local/lib/python3.5/dist-packages/pymc3/plots/kdeplot.py in fast_kde(x)
#      41
#      42     # add small jitter in case input values are the same
# ---> 43     x += np.random.uniform(-1E-12, 1E-12, size=n)
#      44     xmin, xmax = np.min(x), np.max(x)
#      45
#
# TypeError: Cannot cast ufunc add output from dtype('float64') to dtype('bool') with casting rule 'same_kind'
